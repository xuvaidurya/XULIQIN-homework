# %%
# %pip install pandas matplotlib numpy lets plot
# Out:
# Requirement already satisfied: pandas in d:\python\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in d:\python\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy in d:\python\lib\site-packages (1.26.4)
# Requirement already satisfied: lets in d:\python\lib\site-packages (0.1.6)
# Requirement already satisfied: plot in d:\python\lib\site-packages (0.6.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\python\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\python\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\python\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\python\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\python\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: gevent>=1.1.0 in d:\python\lib\site-packages (from lets) (24.10.3)
# Requirement already satisfied: six in d:\python\lib\site-packages (from lets) (1.16.0)
# Requirement already satisfied: typing in d:\python\lib\site-packages (from plot) (3.7.4.3)
# Requirement already satisfied: scipy in d:\python\lib\site-packages (from plot) (1.13.1)
# Requirement already satisfied: pyyaml in d:\python\lib\site-packages (from plot) (6.0.1)
# Requirement already satisfied: zope.event in d:\python\lib\site-packages (from gevent>=1.1.0->lets) (5.0)
# Requirement already satisfied: zope.interface in d:\python\lib\site-packages (from gevent>=1.1.0->lets) (5.4.0)
# Requirement already satisfied: greenlet>=3.1.1 in d:\python\lib\site-packages (from gevent>=1.1.0->lets) (3.1.1)
# Requirement already satisfied: cffi>=1.17.1 in d:\python\lib\site-packages (from gevent>=1.1.0->lets) (1.17.1)
# Requirement already satisfied: pycparser in d:\python\lib\site-packages (from cffi>=1.17.1->gevent>=1.1.0->lets) (2.21)
# Requirement already satisfied: setuptools in d:\python\lib\site-packages (from zope.event->gevent>=1.1.0->lets) (69.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import pingouin as pg
# !pip install lets-plot
from lets_plot import *
LetsPlot.setup_html(no_js=True)
plt.style.use("https://raw.githubusercontent.com/aeturrell/core_python/main/plot_style.txt")

# %%
import pandas as pd

# %%
df = pd.read_csv(
    "https://data.giss.nasa.gov/gistemp/tabledata_v4/NH.Ts+dSST.csv",
    skiprows=1,
    na_values="***",
)

# %%
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.39 -0.54 -0.24 -0.31 -0.05 -0.18 -0.23 -0.27 -0.26 -0.31 -0.46
# 1  1881 -0.31 -0.26 -0.07 -0.03  0.03 -0.34  0.08 -0.06 -0.29 -0.45 -0.38
# 2  1882  0.25  0.20  0.01 -0.31 -0.24 -0.29 -0.28 -0.17 -0.26 -0.53 -0.34
# 3  1883 -0.58 -0.66 -0.15 -0.30 -0.26 -0.11 -0.06 -0.23 -0.34 -0.16 -0.45
# 4  1884 -0.17 -0.11 -0.64 -0.59 -0.36 -0.41 -0.41 -0.51 -0.45 -0.45 -0.58
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.43 -0.31   NaN   NaN -0.20 -0.23 -0.34
# 1 -0.24 -0.19 -0.21 -0.33 -0.02 -0.11 -0.37
# 2 -0.69 -0.22 -0.18  0.07 -0.18 -0.25 -0.38
# 3 -0.15 -0.29 -0.33 -0.64 -0.24 -0.13 -0.32
# 4 -0.47 -0.43 -0.40 -0.14 -0.53 -0.45 -0.49

# %%
df.tail()
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 140  2020  1.59  1.70  1.67  1.40  1.27  1.14  1.10  1.12  1.19  1.21  1.59
# 141  2021  1.25  0.96  1.21  1.13  1.05  1.21  1.07  1.03  1.05  1.30  1.29
# 142  2022  1.25  1.17  1.41  1.09  1.02  1.13  1.06  1.17  1.15  1.31  1.10
# 143  2023  1.30  1.30  1.64  1.02  1.13  1.19  1.45  1.57  1.67  1.88  1.98
# 144  2024  1.68  1.93  1.78  1.80  1.45  1.54  1.42  1.42  1.58  1.72   NaN
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# 140  1.19  1.35  1.36  1.56  1.44  1.12  1.33
# 141  1.17  1.14  1.14  1.13  1.13  1.10  1.21
# 142  1.06  1.16  1.17  1.19  1.17  1.12  1.19
# 143  1.85  1.50  1.43  1.22  1.26  1.40  1.84
# 144   NaN   NaN   NaN  1.82  1.67  1.46   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    145 non-null    int64
#  1   Jan     145 non-null    float64
#  2   Feb     145 non-null    float64
#  3   Mar     145 non-null    float64
#  4   Apr     145 non-null    float64
#  5   May     145 non-null    float64
#  6   Jun     145 non-null    float64
#  7   Jul     145 non-null    float64
#  8   Aug     145 non-null    float64
#  9   Sep     145 non-null    float64
#  10  Oct     145 non-null    float64
#  11  Nov     144 non-null    float64
#  12  Dec     144 non-null    float64
#  13  J-D     144 non-null    float64
#  14  D-N     143 non-null    float64
#  15  DJF     144 non-null    float64
#  16  MAM     145 non-null    float64
#  17  JJA     145 non-null    float64
#  18  SON     144 non-null    float64
# dtypes: float64(18), int64(1)
# memory usage: 21.7 KB

# %%
df = df.set_index("Year")
df.head()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# Year
# 1880 -0.39 -0.54 -0.24 -0.31 -0.05 -0.18 -0.23 -0.27 -0.26 -0.31 -0.46 -0.43
# 1881 -0.31 -0.26 -0.07 -0.03  0.03 -0.34  0.08 -0.06 -0.29 -0.45 -0.38 -0.24
# 1882  0.25  0.20  0.01 -0.31 -0.24 -0.29 -0.28 -0.17 -0.26 -0.53 -0.34 -0.69
# 1883 -0.58 -0.66 -0.15 -0.30 -0.26 -0.11 -0.06 -0.23 -0.34 -0.16 -0.45 -0.15
# 1884 -0.17 -0.11 -0.64 -0.59 -0.36 -0.41 -0.41 -0.51 -0.45 -0.45 -0.58 -0.47
#
#        J-D   D-N   DJF   MAM   JJA   SON
# Year
# 1880 -0.31   NaN   NaN -0.20 -0.23 -0.34
# 1881 -0.19 -0.21 -0.33 -0.02 -0.11 -0.37
# 1882 -0.22 -0.18  0.07 -0.18 -0.25 -0.38
# 1883 -0.29 -0.33 -0.64 -0.24 -0.13 -0.32
# 1884 -0.43 -0.40 -0.14 -0.53 -0.45 -0.49

# %%
df.tail()
# Out:
#        Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# Year
# 2020  1.59  1.70  1.67  1.40  1.27  1.14  1.10  1.12  1.19  1.21  1.59  1.19
# 2021  1.25  0.96  1.21  1.13  1.05  1.21  1.07  1.03  1.05  1.30  1.29  1.17
# 2022  1.25  1.17  1.41  1.09  1.02  1.13  1.06  1.17  1.15  1.31  1.10  1.06
# 2023  1.30  1.30  1.64  1.02  1.13  1.19  1.45  1.57  1.67  1.88  1.98  1.85
# 2024  1.68  1.93  1.78  1.80  1.45  1.54  1.42  1.42  1.58  1.72   NaN   NaN
#
#        J-D   D-N   DJF   MAM   JJA   SON
# Year
# 2020  1.35  1.36  1.56  1.44  1.12  1.33
# 2021  1.14  1.14  1.13  1.13  1.10  1.21
# 2022  1.16  1.17  1.19  1.17  1.12  1.19
# 2023  1.50  1.43  1.22  1.26  1.40  1.84
# 2024   NaN   NaN  1.82  1.67  1.46   NaN

# %%
fig, ax = plt.subplots()
df["Jan"].plot(ax=ax)
ax.set_ylabel("y label")
ax.set_xlabel("x label")
ax.set_title("title")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df.index, df["Jan"])
ax.set_ylabel("y label")
ax.set_xlabel("x label")
ax.set_title("title")
plt.show()

# %%
month = "Jan"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.66, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average temperature anomaly in {month} \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %%
month = "J-D"
fig, ax = plt.subplots()
ax.axhline(0, color="orange")
ax.annotate("1951—1980 average", xy=(0.68, -0.2), xycoords=("figure fraction", "data"))
df[month].plot(ax=ax)
ax.set_title(
    f"Average annual temperature anomaly in \n in the northern hemisphere (1880—{df.index.max()})"
)
ax.set_ylabel("Annual temperature anomalies");

# %%
df["Period"] = pd.cut(
    df.index,
    bins=[1921, 1950, 1980, 2010],
    labels=["1921—1950", "1951—1980", "1981—2010"],
    ordered=True,
)
df["Period"].tail(20)
# Out:
# Year
# 2005    1981—2010
# 2006    1981—2010
# 2007    1981—2010
# 2008    1981—2010
# 2009    1981—2010
# 2010    1981—2010
# 2011          NaN
# 2012          NaN
# 2013          NaN
# 2014          NaN
# 2015          NaN
# 2016          NaN
# 2017          NaN
# 2018          NaN
# 2019          NaN
# 2020          NaN
# 2021          NaN
# 2022          NaN
# 2023          NaN
# 2024          NaN
# Name: Period, dtype: category
# Categories (3, object): ['1921—1950' < '1951—1980' < '1981—2010']

# %%
list_of_months = ["Jun", "Jul", "Aug"]
df[list_of_months].stack().head()
# Out:
# Year
# 1880  Jun   -0.18
#       Jul   -0.23
#       Aug   -0.27
# 1881  Jun   -0.34
#       Jul    0.08
# dtype: float64

# %%
fig, axes = plt.subplots(ncols=3, figsize=(9, 4), sharex=True, sharey=True)
for ax, period in zip(axes, df["Period"].dropna().unique()):
    df.loc[df["Period"] == period, list_of_months].stack().hist(ax=ax)
    ax.set_title(period)
plt.suptitle("Histogram of temperature anomalies")
axes[1].set_xlabel("Summer temperature distribution")
plt.tight_layout();

# %%
# Create a variable that has years 1951 to 1980, and months Jan to Dec (inclusive)
temp_all_months = df.loc[(df.index >= 1951) & (df.index <= 1980), "Jan":"Dec"]
# Put all the data in stacked format and give the new columns sensible names
temp_all_months = (
    temp_all_months.stack()
    .reset_index()
    .rename(columns={"level_1": "month", 0: "values"})
)
# Take a look at this data:
temp_all_months
# Out:
#      Year month  values
# 0    1951   Jan   -0.36
# 1    1951   Feb   -0.51
# 2    1951   Mar   -0.18
# 3    1951   Apr    0.06
# 4    1951   May    0.17
# ..    ...   ...     ...
# 355  1980   Aug    0.10
# 356  1980   Sep    0.10
# 357  1980   Oct    0.12
# 358  1980   Nov    0.21
# 359  1980   Dec    0.09
#
# [360 rows x 3 columns]

# %%
quantiles = [0.3, 0.7]
list_of_percentiles = np.quantile(temp_all_months["values"], q=quantiles)

print(f"The cold threshold of {quantiles[0]*100}% is {list_of_percentiles[0]}")
print(f"The hot threshold of {quantiles[1]*100}% is {list_of_percentiles[1]}")
# Out:
# The cold threshold of 30.0% is -0.1
# The hot threshold of 70.0% is 0.1

# %%
# Create a variable that has years 1981 to 2010, and months Jan to Dec (inclusive)
temp_all_months = df.loc[(df.index >= 1981) & (df.index <= 2010), "Jan":"Dec"]
# Put all the data in stacked format and give the new columns sensible names
temp_all_months = (
    temp_all_months.stack()
    .reset_index()
    .rename(columns={"level_1": "month", 0: "values"})
)
# Take a look at the start of this data data:
temp_all_months.head()
# Out:
#    Year month  values
# 0  1981   Jan    0.80
# 1  1981   Feb    0.62
# 2  1981   Mar    0.68
# 3  1981   Apr    0.39
# 4  1981   May    0.18

# %%
entries_less_than_q30 = temp_all_months["values"] < list_of_percentiles[0]
proportion_under_q30 = entries_less_than_q30.mean()
print(
    f"The proportion under {list_of_percentiles[0]} is {proportion_under_q30*100:.2f}%"
)
# Out:
# The proportion under -0.1 is 1.94%

# %%
proportion_over_q70 = (temp_all_months["values"] > list_of_percentiles[1]).mean()
print(f"The proportion over {list_of_percentiles[1]} is {proportion_over_q70*100:.2f}%")
# Out:
# The proportion over 0.1 is 84.72%

# %%
temp_all_months = (
    df.loc[:, "DJF":"SON"]
    .stack()
    .reset_index()
    .rename(columns={"level_1": "Season", 0: "Values"})
)
temp_all_months["Period"] = pd.cut(
    temp_all_months["Year"],
    bins=[1921, 1950, 1980, 2010],
    labels=["1921—1950", "1951—1980", "1981—2010"],
    ordered=True,
)
# Take a look at a cut of the data using `.iloc`, which provides position
temp_all_months.iloc[-135:-125]
# Out:
#      Year Season  Values     Period
# 443  1991    DJF    0.51  1981—2010
# 444  1991    MAM    0.45  1981—2010
# 445  1991    JJA    0.42  1981—2010
# 446  1991    SON    0.32  1981—2010
# 447  1992    DJF    0.44  1981—2010
# 448  1992    MAM    0.30  1981—2010
# 449  1992    JJA   -0.04  1981—2010
# 450  1992    SON   -0.15  1981—2010
# 451  1993    DJF    0.37  1981—2010
# 452  1993    MAM    0.31  1981—2010

# %%
grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
    [np.mean, np.var]
)
grp_mean_var
# Out:
# C:\Users\小爱\AppData\Local\Temp\ipykernel_4280\1563140002.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
# C:\Users\小爱\AppData\Local\Temp\ipykernel_4280\1563140002.py:1: FutureWarning: The provided callable <function mean at 0x000001EF66ADC220> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
# C:\Users\小爱\AppData\Local\Temp\ipykernel_4280\1563140002.py:1: FutureWarning: The provided callable <function var at 0x000001EF66ADC4A0> is currently using SeriesGroupBy.var. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "var" instead.
#   grp_mean_var = temp_all_months.groupby(["Season", "Period"])["Values"].agg(
#                       mean       var
# Season Period
# DJF    1921—1950 -0.026207  0.057303
#        1951—1980 -0.002333  0.050494
#        1981—2010  0.524333  0.079646
# JJA    1921—1950 -0.052414  0.021290
#        1951—1980 -0.000333  0.014631
#        1981—2010  0.400333  0.067727
# MAM    1921—1950 -0.041724  0.031236
#        1951—1980  0.000333  0.025245
#        1981—2010  0.510333  0.076238
# SON    1921—1950  0.083103  0.027751
#        1951—1980 -0.001000  0.026258
#        1981—2010  0.429333  0.111731

# %%
min_year = 1880
(
    ggplot(temp_all_months, aes(x="Year", y="Values", color="Season"))
    + geom_abline(slope=0, color="black", size=1)
    + geom_line(size=1)
    + labs(
        title=f"Average annual temperature anomaly in \n in the northern hemisphere ({min_year}—{temp_all_months['Year'].max()})",
        y="Annual temperature anomalies",
    )
    + scale_x_continuous(format="d")
    + geom_text(
        x=min_year, y=0.1, label="1951—1980 average", hjust="left", color="black"
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pZT6VGm .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pZT6VGm .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pZT6VGm .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pZT6VGm .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pZT6VGm .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pZT6VGm .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pZT6VGm .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pZT6VGm .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsIzy4Y .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pZT6VGm .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pZT6VGm .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsIzy4Y .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pZT6VGm .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pZT6VGm .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsIzy4Y .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsIzy4Y .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsIzy4Y .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pZT6VGm">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 42.5 ) ">
#       <g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="20.292512015615102" y1="0.0" x2="20.292512015615102" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="76.66060094787917" y1="0.0" x2="76.66060094787917" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="133.02868988014325" y1="0.0" x2="133.02868988014325" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="189.39677881240732" y1="0.0" x2="189.39677881240732" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="245.7648677446714" y1="0.0" x2="245.7648677446714" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="302.13295667693546" y1="0.0" x2="302.13295667693546" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="358.50104560919954" y1="0.0" x2="358.50104560919954" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="414.8691345414636" y1="0.0" x2="414.8691345414636" y2="305.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="288.2380424453595" x2="446.4352643435323" y2="288.2380424453595" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="239.93268926195756" x2="446.4352643435323" y2="239.93268926195756" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="191.6273360785556" x2="446.4352643435323" y2="191.6273360785556" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="143.32198289515364" x2="446.4352643435323" y2="143.32198289515364" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="95.01662971175168" x2="446.4352643435323" y2="95.01662971175168" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="46.711276528349714" x2="446.4352643435323" y2="46.711276528349714" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#c0UhoaH)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (446.4352643435323, 305.0)]">
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <g>
#               <line x1="0.0" y1="191.6273360785556" x2="446.43526434353225" y2="191.62733607855557" stroke="rgb(0,0,0)" stroke-opacity="1.0" fill="none" stroke-width="2.2">
#               </line>
#             </g>
#             <g>
#               <g>
#                 <path d="M20.292512015615102 210.94947735191639 L20.292512015615102 210.94947735191639 L23.110916462228488 193.55955020589167 L25.929320908841873 209.01726322458032 L28.74772535545435 214.81390560658855 L31.566129802067735 242.8310104529617 L34.38453424868112 234.13604687994933 L37.202938695294506 237.03436807095343 L40.02134314190789 226.407190370605 L42.83974758852037 223.5088691796009 L45.65815203513375 187.76290782388344 L48.47655648174714 226.407190370605 L51.294960928360524 212.88169147925245 L54.11336537497391 234.13604687994933 L56.931769821586386 225.44108330693697 L59.75017426819977 223.5088691796009 L62.56857871481316 222.54276211593285 L65.38698316142654 232.20383275261324 L68.20538760803993 201.288406715236 L71.0237920546524 236.0682610072854 L73.84219650126579 225.44108330693697 L76.66060094787917 193.55955020589167 L79.47900539449256 182.93237250554324 L82.29740984110595 228.33940449794108 L85.11581428771842 226.407190370605 L87.93421873433181 237.03436807095343 L90.75262318094519 222.54276211593285 L93.57102762755858 205.15283496990816 L96.38943207417196 235.10215394361737 L99.20783652078444 238.96658219828953 L102.02624096739783 249.59375989863796 L104.84464541401121 230.27161862527717 L107.6630498606246 240.8987963256256 L110.48145430723798 219.64444092492874 L113.29985875385046 239.93268926195756 L116.11826320046384 221.5766550522648 L118.93666764707723 197.42397846056383 L121.75507209369061 227.37329743427307 L124.573476540304 260.2209375989864 L127.39188098691648 234.13604687994933 L130.21028543352986 225.44108330693697 L133.02868988014325 205.15283496990816 L135.84709432675663 2

# %%
df_co2 = pd.read_csv("date/data2.csv")
df_co2.head()
# Out:
#    Year  Month  Monthly average  Interpolated   Trend
# 0  1958      3           315.71        315.71  314.62
# 1  1958      4           317.45        317.45  315.29
# 2  1958      5           317.50        317.50  314.71
# 3  1958      6           -99.99        317.10  314.85
# 4  1958      7           315.86        315.86  314.98

# %%
df_co2_june = df_co2.loc[df_co2["Month"] == 6]
df_co2_june.head()
# Out:
#     Year  Month  Monthly average  Interpolated   Trend
# 3   1958      6           -99.99        317.10  314.85
# 15  1959      6           318.15        318.15  315.92
# 27  1960      6           319.59        319.59  317.36
# 39  1961      6           319.77        319.77  317.48
# 51  1962      6           320.55        320.55  318.27

# %%
df_temp_co2 = pd.merge(df_co2_june, df, on="Year")
df_temp_co2[["Year", "Jun", "Trend"]].head()
# Out:
#    Year   Jun   Trend
# 0  1958  0.05  314.85
# 1  1959  0.14  315.92
# 2  1960  0.18  317.36
# 3  1961  0.18  317.48
# 4  1962 -0.13  318.27

# %%
(
    ggplot(df_temp_co2, aes(x="Jun", y="Trend"))
    + geom_point(color="black", size=3)
    + labs(
        title="Scatterplot of temperature anomalies vs carbon dioxide emissions",
        y="Carbon dioxide levels (trend, mole fraction)",
        x="Temperature anomaly (degrees Celsius)",
    )
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pI8Exm3 .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pI8Exm3 .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI8Exm3 .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI8Exm3 .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pI8Exm3 .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI8Exm3 .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI8Exm3 .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI8Exm3 .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dCHbR6D .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI8Exm3 .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pI8Exm3 .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dCHbR6D .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI8Exm3 .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pI8Exm3 .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dCHbR6D .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dCHbR6D .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dCHbR6D .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pI8Exm3">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="24.275371983345252" y1="0.0" x2="24.275371983345252" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="97.28400952724073" y1="0.0" x2="97.28400952724073" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="170.2926470711362" y1="0.0" x2="170.2926470711362" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="243.30128461503168" y1="0.0" x2="243.30128461503168" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="316.3099221589272" y1="0.0" x2="316.3099221589272" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="389.31855970282265" y1="0.0" x2="389.31855970282265" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="462.32719724671813" y1="0.0" x2="462.32719724671813" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="290.01659923845796" x2="534.0581836335954" y2="290.01659923845796" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="226.35643741075683" x2="534.0581836335954" y2="226.35643741075683" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="162.6962755830557" x2="534.0581836335954" y2="162.6962755830557" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="99.03611375535456" x2="534.0581836335954" y2="99.03611375535456" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="35.37595192765343" x2="534.0581836335954" y2="35.37595192765343" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#cA7tn9r)" clip-bounds-jfx="[rect (29.941816366404606, 0.0), (534.0581836335954, 321.0)]">
#         <g transform="translate(29.941816366404606 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <g >
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="115.5361689132146" cy="306.4090909090909" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="148.39005580796757" cy="303.0032722513089" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="162.99178331674665" cy="298.4197405997144" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="162.99178331674665" cy="298.03777962874824" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="49.82839512370867" cy="295.5232032365541" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="82.68228201846163" cy="292.69032603522123" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="64.43012263248777" cy="291.00333174678724" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="24.275371983345252" cy="291.1306520704427" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="119.18660079040937" cy="285.17842693955265" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="75.38141826407208" cy="283.8415635411709" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="79.03185014126686" cy="279.83097334602576" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="82.68228201846163" cy="275.279271775345" r="3.3000000000000003" />
#                   <circle fill="#000000" stroke="#000000" stroke-opacity="0.0" stroke-width="0.0" cx="104.58487328163028" cy="272.4463945740124" r="3.3000000000000003" />

# %%
df_temp_co2[["Jun", "Trend"]].corr(method="pearson")
# Out:
#            Jun    Trend
# Jun    1.00000  0.91495
# Trend  0.91495  1.00000

# %%
(
    ggplot(df_temp_co2, aes(x="Year", y="Jun"))
    + geom_line(size=1)
    + labs(
        title="June temperature anomalies",
    )
    + scale_x_continuous(format="d")
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pCJIJEL .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #pCJIJEL .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pCJIJEL .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pCJIJEL .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #pCJIJEL .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pCJIJEL .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pCJIJEL .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pCJIJEL .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsjvS6O .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pCJIJEL .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #pCJIJEL .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsjvS6O .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pCJIJEL .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #pCJIJEL .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsjvS6O .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsjvS6O .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dsjvS6O .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#   </style>
#   <g id="pCJIJEL">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(29.5 26.5 ) ">
#       <g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="40.3462901687999" y1="0.0" x2="40.3462901687999" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="121.85394707546402" y1="0.0" x2="121.85394707546402" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="203.36160398212814" y1="0.0" x2="203.36160398212814" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="284.86926088879227" y1="0.0" x2="284.86926088879227" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="366.3769177954564" y1="0.0" x2="366.3769177954564" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="447.8845747021205" y1="0.0" x2="447.8845747021205" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <line x1="0.0" y1="306.40909090909093" x2="528.9846933242504" y2="306.40909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="262.52665755297335" x2="528.9846933242504" y2="262.52665755297335" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="218.64422419685576" x2="528.9846933242504" y2="218.64422419685576" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="174.7617908407382" x2="528.9846933242504" y2="174.7617908407382" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="130.8793574846206" x2="528.9846933242504" y2="130.8793574846206" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="86.99692412850305" x2="528.9846933242504" y2="86.99692412850305" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#             <line x1="0.0" y1="43.114490772385494" x2="528.9846933242504" y2="43.114490772385494" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#             </line>
#           </g>
#         </g>
#       </g>
#       <g clip-path="url(#c8D6vrb)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (528.9846933242504, 321.0)]">
#         <g transform="translate(35.01530667574961 0.0 ) ">
#           <g>
#             <g>
#               <g>
#                 <path d="M24.04475878746598 251.55604921394396 L24.04475878746598 251.55604921394396 L32.19552447813294 231.80895420369103 L40.3462901687999 223.03246753246754 L48.497055859465036 223.03246753246754 L56.647821550131994 291.05023923444975 L64.79858724079895 271.30314422419684 L72.94935293146591 282.27375256322625 L81.10011862213105 306.40909090909093 L89.25088431279801 249.36192754613808 L97.40165000346497 275.6913875598086 L105.5524156941301 273.49726589200276 L113.70318138479706 271.30314422419684 L121.85394707546402 258.13841421736157 L130.00471276612916 293.24436090225566 L138.15547845679612 284.4678742310321 L146.30624414746308 227.42071086807928 L154.45700983812822 302.02084757347916 L162.60777552879517 280.0796308954204 L170.75854121946213 306.40909090909093 L178.9093069101291 212.06185919343812 L187.06007260079423 293.24436090225566 L195.2108382914612 244.97368421052633 L203.36160398212814 220.83834586466165 L211.51236967279328 201.09125085440874 L219.66313536346024 260.3325358851675 L227.8139010541272 238.3913192071087 L235.96466674479234 242.77956254272044 L244.1154324354593 262.52665755297335 L252.26619812612626 231.80895420369103 L260.4169638167932 227.42071086807928 L268.56772950745835 174.7617908407382 L276.7184951981253 209.86773752563226 L284.86926088879227 157.20881749829118 L293.0200265794574 159.40293916609704 L301.17079227012437 253.75017088174982 L309.3215579607913 214.255980861244 L317.47232365145646 172.5676691729323 L325.6230893421234 152.8205741626794 L333.7738550327904 207.67361585782638 L341.9246207234555 155.0146958304853 L350.0753864141225 102.35577580314421 L358.22615210478943 185.73239917976758 L366.3769177954564 165.98530416951468 L374.52768348612153 148.43233082706766 L382.6784491767885 113.3263841421736 L390.82921486745545 144.0440874914559 L398.9799805581206 159.40293916609704 L407.13074624878755 89.19104579630894 L415.2815119394545 84.80280246069717 L423.43227763011964 119.90874914559123 L431.5830433207866 126.49111414900887 L439.73380901145356 115.520505809979

# %%
base_plot = ggplot(df_temp_co2) + scale_x_continuous(format="d")
plot_p = (
    base_plot
    + geom_line(aes(x="Year", y="Jun"), size=1)
    + labs(title="June temperature anomalies")
)
plot_q = (
    base_plot
    + geom_line(aes(x="Year", y="Trend"), size=1)
    + labs(title="Carbon dioxide emissions")
)
gggrid([plot_p, plot_q], ncol=2)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="900.0" height="400.0">
#   <g id="pu6RWTQ">
#     <rect x="0.0" y="0.0" height="400.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
#     </rect>
#   </g>
#   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="448.0" height="400.0" x="0.0" y="0.0">
#     <style type="text/css">
#     .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #p3mOyuy .plot-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 16.0px;
#
# }
# #p3mOyuy .plot-subtitle {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p3mOyuy .plot-caption {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p3mOyuy .hyperlink-element {
# fill: #118ed8;
# font-weight: normal;
#    font-style: normal;
# }
# #p3mOyuy .legend-title {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p3mOyuy .legend-item {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p3mOyuy .axis-title-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p3mOyuy .axis-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dhJd536 .axis-tooltip-text-x {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p3mOyuy .axis-title-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 15.0px;
#
# }
# #p3mOyuy .axis-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dhJd536 .axis-tooltip-text-y {
# fill: #ffffff;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p3mOyuy .facet-strip-text-x {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #p3mOyuy .facet-strip-text-y {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dhJd536 .tooltip-text {
# fill: #474747;
# font-weight: normal;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dhJd536 .tooltip-title {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
# #dhJd536 .tooltip-label {
# fill: #474747;
# font-weight: bold;
#    font-style: normal;font-family: Lucida Grande, sans-serif;
# font-size: 13.0px;
#
# }
#
#     </style>
#     <g id="p3mOyuy">
#       <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L448.0 400.0 L448.0 0.0 Z">
#       </path>
#       <g transform="translate(29.5 26.5 ) ">
#         <g>
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <line x1="28.753069829816013" y1="0.0" x2="28.753069829816013" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="86.84007958701841" y1="0.0" x2="86.84007958701841" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="144.92708934422262" y1="0.0" x2="144.92708934422262" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="203.01409910142502" y1="0.0" x2="203.01409910142502" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="261.10110885862923" y1="0.0" x2="261.10110885862923" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="319.1881186158316" y1="0.0" x2="319.1881186158316" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#             </g>
#           </g>
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <line x1="0.0" y1="306.40909090909093" x2="376.9846933242504" y2="306.40909090909093" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="262.52665755297335" x2="376.9846933242504" y2="262.52665755297335" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="218.64422419685576" x2="376.9846933242504" y2="218.64422419685576" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="174.7617908407382" x2="376.9846933242504" y2="174.7617908407382" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="130.8793574846206" x2="376.9846933242504" y2="130.8793574846206" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="86.99692412850305" x2="376.9846933242504" y2="86.99692412850305" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#               <line x1="0.0" y1="43.114490772385494" x2="376.9846933242504" y2="43.114490772385494" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#               </line>
#             </g>
#           </g>
#         </g>
#         <g clip-path="url(#c7X4mGI)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (376.9846933242504, 321.0)]">
#           <g transform="translate(35.01530667574961 0.0 ) ">
#             <g>
#               <g>
#                 <g>
#                   <path d="M17.13566787837408 251.55604921394396 L17.13566787837408 251.55604921394396 L22.944368854094137 231.80895420369103 L28.753069829816013 223.03246753246754 L34.56177080553607 223.03246753246754 L40.37047178125613 291.05023923444975 L46.179172756976186 271.30314422419684 L51.987873732696244 282.27375256322625 L57.7965747084163 306.40909090909093 L63.60527568413636 249.36192754613808 L69.41397665985824 275.6913875598086 L75.2226776355783 273.49726589200276 L81.03137861129835 271.30314422419684 L86.84007958701841 258.13841421736157 L92.64878056273847 293.24436090225566 L98.45748153845852 284.4678742310321 L104.2661825141804 227.42071086807928 L110.07488348990046 302.02084757347916 L115.88358446562052 280.0796308954204 L121.69228544134057 306.40909090909093 L127.50098641706063 212.06185919343812 L133.3096873927807 293.24436090225566 L139.11838836850075 244.97368421052633 L144.92708934422262 220.83834586466165 L150.73579031994268 201.09125085440874 L156.54449129566274 260.3325358851675 L162.3531922713828 238.3913192071087 L168.16189324710285 242.77956254272044 L173.9705942228229 262.52665755297335 L179.77929519854297 231.80895420369103 L185.58799617426484 227.42071086807928 L191.3966971499849 174.7617908407382 L197.20539812570496 209.86773752563226 L203.01409910142502 157.20881749829118 L208.82280007714508 159.40293916609704 L214.63150105286513 253.75017088174982 L220.440202028587 214.255980861244 L226.24890300430707 172.5676691729323 L232.05760398002712 152.8205741626794 L237.86630495574718 207.67361585782638 L243.67500593146724 1
