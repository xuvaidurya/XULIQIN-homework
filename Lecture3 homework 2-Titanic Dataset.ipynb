# %%
pip install pandas skimpy
# Out:
# ...
#    ---------------------------------------- 0.0/28.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/28.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/28.8 MB 2.8 MB/s eta 0:00:11
#    ---------------------------------------- 0.2/28.8 MB 1.7 MB/s eta 0:00:17
#    ---------------------------------------- 0.3/28.8 MB 2.2 MB/s eta 0:00:14
#     --------------------------------------- 0.5/28.8 MB 2.3 MB/s eta 0:00:13
#     --------------------------------------- 0.5/28.8 MB 2.3 MB/s eta 0:00:13
#     --------------------------------------- 0.5/28.8 MB 1.9 MB/s eta 0:00:16
#     --------------------------------------- 0.6/28.8 MB 1.9 MB/s eta 0:00:16
#    - -------------------------------------- 0.8/28.8 MB 2.2 MB/s eta 0:00:13
#    - -------------------------------------- 0.8/28.8 MB 2.1 MB/s eta 0:00:14
#    - -------------------------------------- 1.0/28.8 MB 2.2 MB/s eta 0:00:13
# ...

# %%
import pandas as pd
import skimpy as sk
url ='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)
skim_summary = sk.skim(df)
print(skim_summary)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 891    │ │ int32       │ 5     │                                                          │
# │ │ Number of columns │ 12     │ │ string      │ 5     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 2     │                                                          │
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
survived_over_30 = df[(df['Age'] > 30) & (df['Survived'] == 1)]
print(survived_over_30)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 21            22         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# ..                                                 ...     ...   ...    ...
# ...
